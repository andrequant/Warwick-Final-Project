# %%
import numpy as np
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import equinox as eqx

import optax

import timeit

# %%
sigma2 = 0.5**2

L = 3.0


a = 0.75
b = 0.75

v_max = 1.5
p_max = 1 # rho_max cannot be learned Susana's paper

# %%
# Define a Multilayer Perceptron

class MLP(eqx.Module):
    layers: list  # Type annotation indicating that layers is a list. Needed to work properly.


    def __init__(self, key, input_dim, hidden_dims, n_layers, output_dim):
        """Define the MLP

        Args:
            key (jax key): Random Jey
            input_dim (int): Input layer dimension
            hidden_dims (int): Hidden layers dimension
            n_layers (_type_): Number of hidden layers
            output_dim (_type_): Output layer dimension
        """


        
        # jax handle random number generation in a different way. Favoring reproducibility.
        # This gives each layer a rnd initialization.
        keys = jax.random.split(key, n_layers + 1)
        
        dims = [input_dim] + [hidden_dims] * n_layers + [output_dim]
        self.layers = [eqx.nn.Linear(dims[i], dims[i + 1], key=keys[i]) for i in range(len(dims) - 1)]

    
    def __call__(self, x):
        """Forward-pass the input through the network

        Args:
            x (jnp.array): Input

        Returns:
            jnp.array: NN output
        """
        for layer in self.layers[:-1]:
            x = jax.nn.mish(layer(x))
        
        x = self.layers[-1](x)
        return x

# %%
def loss(model, sigma2, L, a, b, steps=50):

    x_flat = jnp.linspace(0, L, steps)
    inputs = jnp.concat([x_flat, jnp.array([0.0]), jnp.array([L])])
    

    rho, grad = jax.vmap(jax.value_and_grad(model))(inputs)
    hess = jax.vmap(jax.hessian(model))(inputs)

    dp_dx = grad
    d2p_dx2 = hess

    # PDE Loss
    pde_loss = sigma2*d2p_dx2 - dp_dx*(v_max*(1-2*rho))

    # in loss
    in_loss = sigma2*dp_dx[-2] - rho[-2]*v_max*(1-rho[-2]) + a*(1-rho[-2])

    # out loss
    out_loss = -sigma2*dp_dx[-1] + rho[-1]*v_max*(1-rho[-1]) - b*rho[-1]

    return jnp.average(pde_loss**2) + in_loss**2 + out_loss**2

# %%
# Initialize the model with multiple hidden layers and scalar output layer
model_key = jax.random.PRNGKey(1)

input_dim = 'scalar'
output_dim = 'scalar'
n_layers = 3
n_nodes = 3

model = MLP(model_key, input_dim=input_dim, hidden_dims=n_nodes, n_layers=n_layers, output_dim=output_dim)

# %%
# PSO parameters
n_particles = 30
n_iterations = 1000
w = 0.5  # inertia weight
c1 = 2.0  # cognitive parameter
c2 = 2.0  # social parameter

# Initialize particles
key = jax.random.PRNGKey(0)
particle_keys = jax.random.split(key, n_particles)
particles = [jax.random.normal(k, (sum(x.size for x in jax.tree_util.tree_leaves(model)),)) for k in particle_keys]
velocities = [jax.random.normal(k, (sum(x.size for x in jax.tree_util.tree_leaves(model)),)) for k in particle_keys]
personal_best_positions = particles.copy()
personal_best_scores = [float('inf')] * n_particles
global_best_position = None
global_best_score = float('inf')

def get_model_params(model):
    leaves = jax.tree_util.tree_leaves(model)
    return jnp.concatenate([x.ravel() for x in leaves])

def set_model_params(model, params):
    leaves = jax.tree_util.tree_leaves(model)
    indices = np.cumsum([0] + [x.size for x in leaves])
    new_leaves = [params[indices[i]:indices[i+1]].reshape(x.shape) for i, x in enumerate(leaves)]
    return jax.tree_util.tree_unflatten(jax.tree_util.tree_structure(model), new_leaves)

# %%
# Training loop
for iteration in range(n_iterations):
    for i, particle in enumerate(particles):
        # Update model parameters
        model = set_model_params(model, particle)
        # Calculate loss (fitness)
        fitness = loss(model, sigma2, L, a, b)
        if fitness < personal_best_scores[i]:
            personal_best_scores[i] = fitness
            personal_best_positions[i] = particle
        if fitness < global_best_score:
            global_best_score = fitness
            global_best_position = particle

    # Update velocities and positions
    for i, particle in enumerate(particles):
        r1 = jax.random.uniform(model_key)
        r2 = jax.random.uniform(model_key)
        cognitive_velocity = c1 * r1 * (personal_best_positions[i] - particle)
        social_velocity = c2 * r2 * (global_best_position - particle)
        velocities[i] = w * velocities[i] + cognitive_velocity + social_velocity
        particles[i] = particle + velocities[i]

    # Print loss every 100 iterations
    if iteration % 100 == 0:
        print(f"Iteration {iteration}, Loss: {global_best_score}")

# Set the model to the best found parameters
model = set_model_params(model, global_best_position)
# Out:
# Iteration 0, Loss: 0.05563843995332718
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[131], line 7
#       5 model = set_model_params(model, particle)
#       6 # Calculate loss (fitness)
# ----> 7 fitness = loss(model, sigma2, L, a, b)
#       8 if fitness < personal_best_scores[i]:
#       9     personal_best_scores[i] = fitness
#
# Cell In[36], line 8, in loss(model, sigma2, L, a, b, steps)
#       4 inputs = jnp.concat([x_flat, jnp.array([0.0]), jnp.array([L])])
#       7 rho, grad = jax.vmap(jax.value_and_grad(model))(inputs)
# ----> 8 hess = jax.vmap(jax.hessian(model))(inputs)
#      10 dp_dx = grad
#      11 d2p_dx2 = hess
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\api.py:1214, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1211 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1212 axis_size_ = (axis_size if axis_size is not None else
#    1213               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1214 out_flat = batching.batch(
#    1215     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1216     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1217     spmd_axis_name=spmd_axis_name
#    1218 ).call_wrapped(*args_flat)
#    1219 return tree_unflatten(out_tree(), out_flat)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\api.py:810, in jacfwd.<locals>.jacfun(*args, **kwargs)
#     808 if not has_aux:
#     809   pushfwd: Callable = partial(_jvp, f_partial, dyn_args)
# --> 810   y, jac = vmap(pushfwd, out_axes=(None, -1))(_std_basis(dyn_args))
#     811 else:
#     812   pushfwd: Callable = partial(_jvp, f_partial, dyn_args, has_aux=True)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\api.py:1214, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1211 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1212 axis_size_ = (axis_size if axis_size is not None else
#    1213               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1214 out_flat = batching.batch(
#    1215     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1216     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1217     spmd_axis_name=spmd_axis_name
#    1218 ).call_wrapped(*args_flat)
#    1219 return tree_unflatten(out_tree(), out_flat)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\api.py:1930, in _jvp(fun, primals, tangents, has_aux)
#    1928 if not has_aux:
#    1929   flat_fun, out_tree = flatten_fun_nokwargs(fun, tree_def)
# -> 1930   out_primals, out_tangents = ad.jvp(flat_fun).call_wrapped(ps_flat, ts_flat)
#    1931   out_tree = out_tree()
#    1932   return (tree_unflatten(out_tree, out_primals),
#    1933           tree_unflatten(out_tree, out_tangents))
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\api.py:897, in jacrev.<locals>.jacfun(*args, **kwargs)
#     895 tree_map(partial(_check_input_dtype_jacrev, holomorphic, allow_int), dyn_args)
#     896 if not has_aux:
# --> 897   y, pullback = _vjp(f_partial, *dyn_args)
#     898 else:
#     899   y, pullback, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\api.py:2176, in _vjp(fun, has_aux, *primals)
#    2174 if not has_aux:
#    2175   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2176   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2177   out_tree = out_tree()
#    2178 else:
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\interpreters\ad.py:143, in vjp(traceable, primals, has_aux)
#     141 def vjp(traceable, primals, has_aux=False):
#     142   if not has_aux:
# --> 143     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     144   else:
#     145     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\interpreters\ad.py:132, in linearize(traceable, *primals, **kwargs)
#     130 _, in_tree = tree_flatten(((primals, primals), {}))
#     131 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 132 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     133 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     134 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\interpreters\partial_eval.py:777, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     775 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     776   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 777   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     778   assert not env
#     779   del main, fun, env
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# Cell In[35], line 38, in MLP.__call__(self, x)
#      29 """Forward-pass the input through the network
#      30
#      31 Args:
#    (...)
#      35     jnp.array: NN output
#      36 """
#      37 for layer in self.layers[:-1]:
# ---> 38     x = jax.nn.mish(layer(x))
#      40 x = self.layers[-1](x)
#      41 return x
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1264.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\equinox\nn\_linear.py:102, in Linear.__call__(self, x, key)
#     100         raise ValueError("x must have scalar shape")
#     101     x = jnp.broadcast_to(x, (1,))
# --> 102 x = self.weight @ x
#     103 if self.bias is not None:
#     104     x = x + self.bias
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\numpy\array_methods.py:265, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     263 args = (other, self) if swap else (self, other)
#     264 if isinstance(other, _accepted_binop_types):
# --> 265   return binary_op(*args)
#     266 # Note: don't use isinstance here, because we don't want to raise for
#     267 # subclasses, e.g. NamedTuple objects that may override operators.
#     268 if type(other) in _rejected_binop_types:
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\pjit.py:327, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     325 @api_boundary
#     326 def cache_miss(*args, **kwargs):
# --> 327   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     328       jit_info, *args, **kwargs)
#     329   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     330   pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\pjit.py:185, in _python_pjit_helper(jit_info, *args, **kwargs)
#     182   args_flat = [*init_states, *args_flat]
#     184 try:
# --> 185   out_flat = pjit_p.bind(*args_flat, **params)
#     186 except pxla.DeviceAssignmentMismatchError as e:
#     187   fails, = e.args
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:2834, in AxisPrimitive.bind(self, *args, **params)
#    2830 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2831                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2832 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833              else axis_main.with_cur_sublevel())
# -> 2834 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\interpreters\ad.py:315, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     313   msg = f"Differentiation rule for '{primitive}' not implemented"
#     314   raise NotImplementedError(msg)
# --> 315 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     316 if primitive.multiple_results:
#     317   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\pjit.py:1972, in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline)
#    1970 _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    1971 _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 1972 outputs = pjit_p.bind(
#    1973     *primals_in, *_filter_zeros_in(tangents_in),
#    1974     jaxpr=jaxpr_jvp,
#    1975     in_shardings=(*in_shardings, *_filter_zeros_in(in_shardings)),
#    1976     out_shardings=(*out_shardings, *_filter_zeros_out(out_shardings)),
#    1977     in_layouts=(*in_layouts, *_filter_zeros_in(in_layouts)),
#    1978     out_layouts=(*out_layouts, *_filter_zeros_out(out_layouts)),
#    1979     resource_env=resource_env,
#    1980     donated_invars=(*donated_invars, *_filter_zeros_in(donated_invars)),
#    1981     name=name,
#    1982     keep_unused=keep_unused,
#    1983     inline=inline)
#    1985 primals_out, tangents_out = split_list(outputs, [len(jaxpr.jaxpr.outvars)])
#    1986 assert len(primals_out) == len(jaxpr.jaxpr.outvars)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:2834, in AxisPrimitive.bind(self, *args, **params)
#    2830 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2831                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2832 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833              else axis_main.with_cur_sublevel())
# -> 2834 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\interpreters\partial_eval.py:214, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     212 def process_primitive(self, primitive, tracers, params):
#     213   if primitive in custom_partial_eval_rules:
# --> 214     return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     215   else:
#     216     return self.default_process_primitive(primitive, tracers, params)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\pjit.py:2069, in _pjit_partial_eval(trace, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *in_tracers)
#    2067 # Bind known things to pjit_p.
#    2068 known_inputs = [pv.get_known() for pv in in_pvals if pv.is_known()]
# -> 2069 all_known_outs = pjit_p.bind(*known_inputs, **known_params)
#    2070 # Add back in the output fwds.
#    2071 all_known_outs = subs_list(out_fwd, all_known_outs, all_known_outs)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:2834, in AxisPrimitive.bind(self, *args, **params)
#    2830 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2831                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2832 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833              else axis_main.with_cur_sublevel())
# -> 2834 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\interpreters\ad.py:315, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     313   msg = f"Differentiation rule for '{primitive}' not implemented"
#     314   raise NotImplementedError(msg)
# --> 315 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     316 if primitive.multiple_results:
#     317   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\pjit.py:1972, in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline)
#    1970 _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    1971 _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 1972 outputs = pjit_p.bind(
#    1973     *primals_in, *_filter_zeros_in(tangents_in),
#    1974     jaxpr=jaxpr_jvp,
#    1975     in_shardings=(*in_shardings, *_filter_zeros_in(in_shardings)),
#    1976     out_shardings=(*out_shardings, *_filter_zeros_out(out_shardings)),
#    1977     in_layouts=(*in_layouts, *_filter_zeros_in(in_layouts)),
#    1978     out_layouts=(*out_layouts, *_filter_zeros_out(out_layouts)),
#    1979     resource_env=resource_env,
#    1980     donated_invars=(*donated_invars, *_filter_zeros_in(donated_invars)),
#    1981     name=name,
#    1982     keep_unused=keep_unused,
#    1983     inline=inline)
#    1985 primals_out, tangents_out = split_list(outputs, [len(jaxpr.jaxpr.outvars)])
#    1986 assert len(primals_out) == len(jaxpr.jaxpr.outvars)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:2834, in AxisPrimitive.bind(self, *args, **params)
#    2830 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2831                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2832 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833              else axis_main.with_cur_sublevel())
# -> 2834 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\interpreters\batching.py:433, in BatchTrace.process_primitive(self, primitive, tracers, params)
#     431   frame = self.get_frame(vals_in, dims_in)
#     432   batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 433   val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     434 src = source_info_util.current()
#     435 if primitive.multiple_results:
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\pjit.py:1895, in _pjit_batcher(insert_axis, spmd_axis_name, axis_size, axis_name, main_type, vals_in, dims_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline)
#    1891 if not (all(l is None for l in in_layouts) and
#    1892         all(l is None for l in out_layouts)):
#    1893   raise NotImplementedError
# -> 1895 vals_out = pjit_p.bind(
#    1896   *vals_in,
#    1897   jaxpr=new_jaxpr,
#    1898   in_shardings=in_shardings,
#    1899   out_shardings=out_shardings,
#    1900   in_layouts=in_layouts,
#    1901   out_layouts=out_layouts,
#    1902   resource_env=resource_env,
#    1903   donated_invars=donated_invars,
#    1904   name=name,
#    1905   keep_unused=keep_unused,
#    1906   inline=inline)
#    1908 resolved_axes_out = batching.resolve_ragged_axes_against_inputs_outputs(
#    1909     vals_in, vals_out, axes_out)
#    1910 return vals_out, resolved_axes_out
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:2834, in AxisPrimitive.bind(self, *args, **params)
#    2830 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2831                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2832 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833              else axis_main.with_cur_sublevel())
# -> 2834 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\interpreters\batching.py:433, in BatchTrace.process_primitive(self, primitive, tracers, params)
#     431   frame = self.get_frame(vals_in, dims_in)
#     432   batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 433   val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     434 src = source_info_util.current()
#     435 if primitive.multiple_results:
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\pjit.py:1895, in _pjit_batcher(insert_axis, spmd_axis_name, axis_size, axis_name, main_type, vals_in, dims_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline)
#    1891 if not (all(l is None for l in in_layouts) and
#    1892         all(l is None for l in out_layouts)):
#    1893   raise NotImplementedError
# -> 1895 vals_out = pjit_p.bind(
#    1896   *vals_in,
#    1897   jaxpr=new_jaxpr,
#    1898   in_shardings=in_shardings,
#    1899   out_shardings=out_shardings,
#    1900   in_layouts=in_layouts,
#    1901   out_layouts=out_layouts,
#    1902   resource_env=resource_env,
#    1903   donated_invars=donated_invars,
#    1904   name=name,
#    1905   keep_unused=keep_unused,
#    1906   inline=inline)
#    1908 resolved_axes_out = batching.resolve_ragged_axes_against_inputs_outputs(
#    1909     vals_in, vals_out, axes_out)
#    1910 return vals_out, resolved_axes_out
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:2834, in AxisPrimitive.bind(self, *args, **params)
#    2830 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2831                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2832 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833              else axis_main.with_cur_sublevel())
# -> 2834 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\core.py:921, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     919   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     920 else:
# --> 921   return primitive.impl(*tracers, **params)
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\pjit.py:1635, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1632 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1633 has_explicit_sharding = _pjit_explicit_sharding(
#    1634     in_shardings, out_shardings, None, None)
# -> 1635 return xc._xla.pjit(
#    1636     name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1637     tree_util.dispatch_registry,
#    1638     lambda x, sharding: pxla.shard_args([sharding], [x])[0],
#    1639     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# KeyboardInterrupt:

# %%
# PSO parameters
n_particles = 30
n_iterations = 1000
w = 0.5  # inertia weight
c1 = 2.0  # cognitive parameter
c2 = 2.0  # social parameter

# Initialize particles
key = jax.random.PRNGKey(0)
particle_keys = jax.random.split(key, n_particles)
particles = [jax.random.normal(k, (sum(x.size for x in jax.tree_util.tree_leaves(model)),)) for k in particle_keys]
velocities = [jax.random.normal(k, (sum(x.size for x in jax.tree_util.tree_leaves(model)),)) for k in particle_keys]
personal_best_positions = particles.copy()
personal_best_scores = [float('inf')] * n_particles
global_best_position = None
global_best_score = float('inf')

def get_model_params(model):
    leaves = jax.tree_util.tree_leaves(model)
    return jnp.concatenate([x.ravel() for x in leaves])

def set_model_params(model, params):
    leaves = jax.tree_util.tree_leaves(model)
    indices = np.cumsum([0] + [x.size for x in leaves])
    new_leaves = [jnp.array(params)[indices[i]:indices[i+1]].reshape(x.shape) for i, x in enumerate(leaves)]
    return jax.tree_util.tree_unflatten(jax.tree_util.tree_structure(model), new_leaves)

@jax.jit
def compute_fitness(params, sigma2, L, a, b, model):
    model = set_model_params(model, params)
    return loss(model, sigma2, L, a, b)

@jax.jit
def update_particles(particles, velocities, personal_best_positions, global_best_position, r1, r2, w, c1, c2):
    cognitive_velocity = c1 * r1 * (personal_best_positions - particles)
    social_velocity = c2 * r2 * (global_best_position - particles)
    new_velocities = w * velocities + cognitive_velocity + social_velocity
    new_particles = particles + new_velocities
    return new_particles, new_velocities

# Vectorize the fitness computation across all particles
compute_fitness_vectorized = jax.vmap(compute_fitness, in_axes=(0, None, None, None, None, None))

# %%
# Training loop
for iteration in range(n_iterations):
    fitness_values = compute_fitness_vectorized(particles, sigma2, L, a, b, model)
    
    # Update personal bests and global best
    for i in range(n_particles):
        if fitness_values[i] < personal_best_scores[i]:
            personal_best_scores[i] = fitness_values[i]
            personal_best_positions[i] = particles[i]
        if fitness_values[i] < global_best_score:
            global_best_score = fitness_values[i]
            global_best_position = particles[i]
    
    # Generate random coefficients for velocity update
    r1 = jax.random.uniform(model_key, shape=(n_particles, particles[0].shape[0]))
    r2 = jax.random.uniform(model_key, shape=(n_particles, particles[0].shape[0]))
    
    # Update particles and velocities
    particles, velocities = update_particles(
        jnp.array(particles), jnp.array(velocities),
        jnp.array(personal_best_positions), jnp.array(global_best_position),
        r1, r2, w, c1, c2
    )

    # Print loss every 100 iterations
    if iteration % 100 == 0:
        print(f"Iteration {iteration}, Loss: {global_best_score}")

# Set the model to the best found parameters
model = set_model_params(model, global_best_position)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[142], line 3
#       1 # Training loop
#       2 for iteration in range(n_iterations):
# ----> 3     fitness_values = compute_fitness_vectorized(particles, sigma2, L, a, b, model)
#       5     # Update personal bests and global best
#       6     for i in range(n_particles):
#
#     [... skipping hidden 14 frame]
#
# Cell In[141], line 30, in compute_fitness(params, sigma2, L, a, b, model)
#      28 @jax.jit
#      29 def compute_fitness(params, sigma2, L, a, b, model):
# ---> 30     model = set_model_params(model, params)
#      31     return loss(model, sigma2, L, a, b)
#
# Cell In[141], line 25, in set_model_params(model, params)
#      23 leaves = jax.tree_util.tree_leaves(model)
#      24 indices = np.cumsum([0] + [x.size for x in leaves])
# ---> 25 new_leaves = [jnp.array(params)[indices[i]:indices[i+1]].reshape(x.shape) for i, x in enumerate(leaves)]
#      26 return jax.tree_util.tree_unflatten(jax.tree_util.tree_structure(model), new_leaves)
#
#     [... skipping hidden 2 frame]
#
# File c:\Users\andre\OneDrive\Documentos\Warwick\Individual Project\Code\Warwick-Final-Project\venv\Lib\site-packages\jax\_src\numpy\array_methods.py:137, in _compute_newshape(a, newshape)
#     134 else:
#     135   if (all(isinstance(d, int) for d in (*np.shape(a), *newshape)) and
#     136       np.size(a) != math.prod(newshape)):
# --> 137     raise TypeError(f"cannot reshape array of shape {np.shape(a)} (size {np.size(a)}) "
#     138                     f"into shape {orig_newshape} (size {math.prod(newshape)})")
#     139 return tuple(-core.divide_shape_sizes(np.shape(a), newshape)
#     140              if core.definitely_equal(d, -1) else d for d in newshape)
#
# TypeError: cannot reshape array of shape (0,) (size 0) into shape (1, 3) (size 3)

# %%
@eqx.filter_jit # decorator that applies Just-in-time compilation just to the relevant parts. Improves performance.
def train_step(model, opt_state, L, sigma2, a, b, steps=20):
    loss_value, grads = jax.value_and_grad(loss)(model, sigma2, L, a, b) # Compute the loss and gradient
    updates, opt_state = optimizer.update(grads, opt_state) # Apply the backward propagation
    model = eqx.apply_updates(model, updates) # Update the NN
    return model, opt_state, loss_value

# %%
# Optimizer definition
lr = 10e-4
optimizer = optax.adam(learning_rate=lr)
opt_state = optimizer.init(model)

# %%
# Training loop
num_epochs = 10000
losses = []

sigma2 = 0.5**2


for epoch in range(num_epochs):
    
    model, opt_state, loss_value = train_step(model, opt_state, L, sigma2, a, b, steps=200)

    if epoch % 100 == 0:
        losses.append(loss_value)
        print(f"Epoch {epoch}, Loss: {loss_value}")

        
    if epoch % 1000 == 0:
        lr *= 0.4
        optimizer = optax.adam(learning_rate=lr)
        opt_state = optimizer.init(model)  # Re-initialize optimizer state with new learning rate



# Print final loss
final_loss = loss(model, L, sigma2, a, b, steps=20)
print(f"Final Loss: {final_loss}")
# Out:
# Epoch 0, Loss: 3.3649051189422607
# Epoch 100, Loss: 0.6583548188209534
# Epoch 200, Loss: 0.20324784517288208
# Epoch 300, Loss: 0.12363242357969284
# Epoch 400, Loss: 0.08543533831834793
# Epoch 500, Loss: 0.04002106562256813
# Epoch 600, Loss: 0.031140180304646492
# Epoch 700, Loss: 0.030779216438531876
# Epoch 800, Loss: 0.03067518025636673
# Epoch 900, Loss: 0.030574560165405273
# Epoch 1000, Loss: 0.0304742269217968
# Epoch 1100, Loss: 0.029191453009843826
# Epoch 1200, Loss: 0.02875533141195774
# Epoch 1300, Loss: 0.028714673593640327
# Epoch 1400, Loss: 0.028697365894913673
# Epoch 1500, Loss: 0.028681080788373947
# Epoch 1600, Loss: 0.028665846213698387
# Epoch 1700, Loss: 0.028651002794504166
# Epoch 1800, Loss: 0.02863633818924427
# Epoch 1900, Loss: 0.028621751815080643
# Epoch 2000, Loss: 0.02860664762556553
# Epoch 2100, Loss: 0.028589705005288124
# Epoch 2200, Loss: 0.028566980734467506
# Epoch 2300, Loss: 0.02853696420788765
# Epoch 2400, Loss: 0.028489001095294952
# Epoch 2500, Loss: 0.02837412618100643
# Epoch 2600, Loss: 0.028238268569111824
# Epoch 2700, Loss: 0.028228141367435455
# Epoch 2800, Loss: 0.02822052128612995
# Epoch 2900, Loss: 0.0282127745449543
# Epoch 3000, Loss: 0.028204897418618202
# Epoch 3100, Loss: 0.028202969580888748
# Epoch 3200, Loss: 0.02819986082613468
# Epoch 3300, Loss: 0.028195645660161972
# Epoch 3400, Loss: 0.02819039858877659
# Epoch 3500, Loss: 0.028184039518237114
# Epoch 3600, Loss: 0.028176451101899147
# Epoch 3700, Loss: 0.02816745638847351
# Epoch 3800, Loss: 0.028156764805316925
# Epoch 3900, Loss: 0.028143983334302902
# Epoch 4000, Loss: 0.028128618374466896
# Epoch 4100, Loss: 0.02812262438237667
# Epoch 4200, Loss: 0.02811303362250328
# Epoch 4300, Loss: 0.02809949964284897
# Epoch 4400, Loss: 0.02808157540857792
# Epoch 4500, Loss: 0.02805805578827858
# Epoch 4600, Loss: 0.028027068823575974
# Epoch 4700, Loss: 0.02798626571893692
# Epoch 4800, Loss: 0.02793344296514988
# Epoch 4900, Loss: 0.027852728962898254
# Epoch 5000, Loss: 0.027715161442756653
# Epoch 5100, Loss: 0.027663955464959145
# Epoch 5200, Loss: 0.027563411742448807
# Epoch 5300, Loss: 0.027355732396245003
# Epoch 5400, Loss: 0.0267710592597723
# Epoch 5500, Loss: 0.013597264885902405
# Epoch 5600, Loss: 0.012843039818108082
# Epoch 5700, Loss: 0.012654016725718975
# Epoch 5800, Loss: 0.012496523559093475
# Epoch 5900, Loss: 0.012347160838544369
# Epoch 6000, Loss: 0.01219254732131958
# Epoch 6100, Loss: 0.0119608324021101
# Epoch 6200, Loss: 0.011571282520890236
# Epoch 6300, Loss: 0.011016334407031536
# Epoch 6400, Loss: 0.010183675214648247
# Epoch 6500, Loss: 0.008835547603666782
# Epoch 6600, Loss: 0.007182511501014233
# Epoch 6700, Loss: 0.005989184137433767
# Epoch 6800, Loss: 0.005399481393396854
# Epoch 6900, Loss: 0.005113675259053707
# Epoch 7000, Loss: 0.004940410610288382
# Epoch 7100, Loss: 0.004901908803731203
# Epoch 7200, Loss: 0.004847746808081865
# Epoch 7300, Loss: 0.004779596347361803
# Epoch 7400, Loss: 0.004699945915490389
# Epoch 7500, Loss: 0.004610658157616854
# Epoch 7600, Loss: 0.004516151733696461
# Epoch 7700, Loss: 0.004423796199262142
# Epoch 7800, Loss: 0.004339303355664015
# Epoch 7900, Loss: 0.004260162357240915
# Epoch 8000, Loss: 0.004180265590548515
# Epoch 8100, Loss: 0.004162947181612253
# Epoch 8200, Loss: 0.004141072276979685
# Epoch 8300, Loss: 0.004116279538720846
# Epoch 8400, Loss: 0.004090230446308851
# Epoch 8500, Loss: 0.004061906132847071
# Epoch 8600, Loss: 0.004029377363622189
# Epoch 8700, Loss: 0.003990727476775646
# Epoch 8800, Loss: 0.003943629562854767
# Epoch 8900, Loss: 0.0038839783519506454
# Epoch 9000, Loss: 0.0038042922969907522
# Epoch 9100, Loss: 0.0037764718290418386
# Epoch 9200, Loss: 0.003734281752258539
# Epoch 9300, Loss: 0.0036710542626678944
# Epoch 9400, Loss: 0.003580395132303238
# Epoch 9500, Loss: 0.0034516167361289263
# Epoch 9600, Loss: 0.003273947862908244
# Epoch 9700, Loss: 0.0030408150050789118
# Epoch 9800, Loss: 0.002741502597928047
# Epoch 9900, Loss: 0.0023327404633164406
# Final Loss: 0.16049204766750336
